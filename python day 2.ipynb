# %%
"""
注册页面
"""


import numpy as np
import random

class mailbox(object):
    
    def address(self):
        shuru = input("邮件地址")
        print(shuru)
        self.password()
    def password(self):
        for i in range(4):
            fillin = input("密码")
            fillin1 = input("确认密码")
            if fillin == fillin1:
                print("继续")
                self.Verification()
                break
            else:
                print("两次填写的密码不一致")
        else:
            print("您可能是一个机器人")
            
    def Verification(self):
        for i in range(3):
            b1 = random.randrange(1000,9999)
            print("验证码是: %d"%b1)
            b = input("请输入验证码")
            if b1 == int(b):
                print("继续")
                break
            else:
                print("请输入正确的验证码")
        else:
            print('您可能是一个机器人  滚')

                          
def main():
    a = mailbox()
    a.address()
main()
# Out:
# 邮件地址123
# 123
# 密码123
# 确认密码123
# 继续
# 验证码是: 7440
# 请输入验证码123
# 请输入正确的验证码
# 验证码是: 3896
# 请输入验证码123
# 请输入正确的验证码
# 验证码是: 3593
# 请输入验证码123
# 请输入正确的验证码
# 您可能是一个机器人  滚

# %%
"""
输入三个数字（私有），求三个数字的和，
尝试更改其中两个数字
"""

class num(object):
    def __init__(self,a,b,c):
        self.__a = a
        self.__b = b
        self.__c = c
    @property
    def A(self):
        print(self.__a)
    @A.setter
    def A(self,a1):
        self.__a = a1
    @property
    def B(self):
        print(self.__b)
    @B.setter
    def B(self,b1):
        self.__b = b1
    @property
    def C(self,c1):
        print(self.__c)
    @C.setter
    def C(self,c1):
        self.__c = c1
        
    def play(self):
        print(self.__a + self.__b + self.__c)
        
number = num(1,2,8)
number.B = 22
number.C = 98228
number.play()
# Out:
# 98251

# %%
class space(object):
    def __init__(self):
        self._art = "konijaisjasdcxzcsandma,sd"
    @property
    def art(self):
        return self._art
    @art.setter
    def art(self,str_):
        self._art = str_
        
        
spa = space()
print(space.art)
space.art = "sadasdcxczcdas"
print(space.art)
# Out:
# <property object at 0x7f594130a368>
# sadasdcxczcdas

# %%
import random

class Regist(object):
    """
    Implementation resgist in 163.
    """
    def account(self):
        """
        Input account.
        """
        # 检测邮箱的正确性.
        # input 返回出来的是一个字符串
        email = input('请输入邮箱:>>')
        print('📮 您输入的邮箱是: %s' % email)
        self.password()
    def password(self):
        """
        input passward,
        """
        # 密码的长度必须是6-20位
        # 密码必须含有大写小写字母以及数字.
        for _ in range(4):
            password_1 = input('请输入您的密码:>>')
            password_2 = input('请输入确认密码:>>')
            if password_1 == password_2:
                print('密码确认成功')
                self.verfily()
                break
            else:
                print('两次密码不一致')
        else:
            print('您可能是一个机器人滚😡')

    def verfily(self):
        """
        ver...
        """
        # 英文和数字的结合
        # 给予一个简单的数学运算得到结果.
        for _ in range(3):
            number = random.randrange(1000,9999)
            print('验证码是: %d'%number)
            number_2 = input('输入验证码:>>')
            if number == int(number_2):
                print('注册成功')
                break
            else:
                print('验证码错误')
        else:
            print('机器人😡')


def main():
    regist = Regist()
    regist.account()

main()
# Out:
# 请输入邮箱:>>wqdsda
# 📮 您输入的邮箱是: wqdsda
# 请输入您的密码:>>dsa
# 请输入确认密码:>>qw
# 两次密码不一致
# 请输入您的密码:>>das
# 请输入确认密码:>>qw
# 两次密码不一致
# 请输入您的密码:>>dsa
# 请输入确认密码:>>qwe
# 两次密码不一致
# 请输入您的密码:>>asd
# 请输入确认密码:>>asd
# 密码确认成功
# 验证码是: 8208
# 输入验证码:>>8208
# 注册成功

# %%
"""
python day2 -1
设计一个名为Rectangle的类来表示矩形


"""

class Rectangle(object):
    
    def __init__(self,width = 1,height = 2):
        self.width = width
        self.height = height
    def getArea(self):
        """矩形的面积"""
        a = self.width * self.height
        print("area:%d" % a)
    def getPerimeter(self):
        """矩形的周长"""
        b = self.width * 2 + self.height * 2
        print("perimeter:%d" % b)
def main():
    rectangle = Rectangle(90,20)
    rectangle.getArea()
    rectangle.getPerimeter()
main()
# Out:
# area:1800
# perimeter:220

# %%
"""
python day2 -2
设计一个名为Account的类

"""
class Account(object):
    def __init__(self):
        pass
    def _id(self):
        pass
    def _balance(self):
        pass
    def _annualInterestRate(self):
        pass
    def getMonthlyInterestRate(self):
        pass
    def getMonthlyInterest(self):
        pass
    def withdraw(self):
        pass
    def deposit(self):
        pass
# Out:
#   File "<ipython-input-8-e9d8ffd704c4>", line 20
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
"""
python day2 -3
设计一个名为Fan的类表示风扇

"""
class Fan(object):
    def __init__(self,radius,sudu,on):
        self.__radius = radius
        self.__sudu = sudu
        self.__on = on
        
    def seed(self):
        if self.__sudu == 1:
            print("SLOW档")
        elif self.__sudu == 2:
            print("MEDIUM档")
        elif self.__sudu == 3:
            print("FAST档")  
    def On(self):
        if self.__on == "False":
            print("关闭")
        else:
            print("打开")
    def radius(self):
        return self.__radius
    def Color(self,color):
        self.__color = color
        return self.__color
Fan = Fan(0,0,"Fause")
Fan.On()
# Out:
# 打开

# %%
"""

python day2 -4
设计一个名为RegularPolygon的类
包括：
一个名为n的私有整型数据域定义多边形的边数。
一个名为side的私有浮点数据域存储边的长度
一个名为x的私有浮点数据域定义多边形中心的x轴坐标值，默认值为0
一个名为y的私有浮点数据域定义多边形中心的y轴坐标值，默认值为0
一个构造方法创建一个具有指定边数n（默认值为3），边长（默认值是1），x（默认值是0）
和y（默认值是0）的正多边形
所有数据域的访问量和修改器
方法getPerimeter（）返回多边形的周长
方法getArea（）返回多边形的面积

"""
import math
class RegularPolygon(object):
    def __init__(self,n=3,length=1,x = 0,y = 0):
        self.__n = n
        self.__length = length
        self.__x = x
        self.__y = y
    def N(self):
        return self.__n
    def side(self):
        return self.__length
    def getPerimeter(self):
        perimeter = self.__n * self.__length
        return perimeter
    def getArea(self):
        area = round((self.__n * self.getPerimeter() * self.getPerimeter()) /( 4 * math.tan(math.pi/4)),2)
        return area
def main():
    Re = RegularPolygon() 
    a = Re.getPerimeter()
    b = Re.getArea()
    n = Re.N()
    length = Re.side()
    print("这是一个",n,"边形","边长是",length,"周长为",a,"面积为",b)
main()
# Out:
# 这是一个 3 边形 边长是 2 周长为 6 面积为 27.0

# %%
"""

python day2 -5
设计一个名为Linearquation的类，它是2 x 2的线性方程式


"""
class Linearquation的类，它是2 x 2的线性方程式(object):
    def __init__(self,a,b,c,d,e,f):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__d = d
        self.__e = e
        self.__f = f
    def get_a(self):
        return self.__a
    def get_b(self):
        return self.__b
    def get_c(self):
        return self.__c
    def get_d(self):
        return self.__d
    def get_e(self):
        return self.__e
    def isSolvable(self):
        if (self.__a * self.__d  - self.__b * self.__c) != 0:
            print("True")
        else:
            print("这个方程无解")
            
    def get(self):
        x = (self.__e * self.__d  - self.__b * self.__f) / (self.__a * self.__d  - self.__b * self.__c)
        y = (self.__a * self.__f  - self.__e * self.__c) / (self.__a * self.__d  - self.__b * self.__c)
        return x,y
        print(89789)
A = Linearquation(10,23,33,43,53,89)
A.get()

# %%
"""

python day2 -6
假设有两条线段相交。第一条线段的两个端点是（x1,y1）和（x2,y2），第二条线段的两个端点是
（x3,y3）和（x4,y4）。编写程序提示用户输入着四个端点，然后显示他们的交点

"""

class Linearquation(object):
    def __init__(self,x1,y1,x2,y2,x3,y3,x4,y4):
        self.__x1 = x1
        self.__y1 = y1
        self.__x2 = x2
        self.__y2 = y2
        self.__x3 = x3
        self.__y3 = y3
        self.__x4 = x4
        self.__y4 = y4
    def num(self):
        k1 = (self.__y2 - self.__y1) / (self.__x2 - self.__x1)
        k2 = (self.__y4 - self.__y3) / (self.__x4 - self.__x3)
        b1 = self.__y1 - k1 * self.__x1
        b2 = self.__y3 - k2 * self.__x3
        X = (b2 - b1) / (k1 - k2)
        Y = k1 * X + b1
        return X,Y
def main():
    x1 = eval(input("请输入x1的值"))
    y1 = eval(input("请输入y1的值"))
    x2 = eval(input("请输入x2的值"))
    y2 = eval(input("请输入y2的值"))
    x3 = eval(input("请输入x3的值"))
    y3 = eval(input("请输入y3的值"))
    x4 = eval(input("请输入x4的值"))
    y4 = eval(input("请输入y4的值"))
    Li = Linearquation(x1,y1,x2,y2,x3,y3,x4,y4)
    
    a = Li.num()
    print("两条直线的交点为：",a)
main()
# Out:
# 请输入x1的值1
# 请输入y1的值23
# 请输入x2的值4
# 请输入y2的值5
# 请输入x3的值65
# 请输入y3的值76
# 请输入x4的值8
# 请输入y4的值79
# 两条直线的交点为： (-8.477876106194689, 79.86725663716814)
