# %%
import numpy as np
a = [1,2,3,4,5]
b = np.array(a)
print(b)
display(b)
print(type(b))
# Out:
# [1 2 3 4 5]
# array([1, 2, 3, 4, 5])
# <class 'numpy.ndarray'>

# %%
c = [[1,2],[3,4]]
d = np.array(c)
display(d)
display(d.shape)
# Out:
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
display(b.shape)
display(d.shape)
# Out:
# (5,)
# (2, 2)

# %%
display(b.size)
display(d.size)
# Out:
# 5
# 4

# %%
ha = [4,5,6,7]
la = [1.1,1.2,1.3]
ha_array =np.array(ha)
la_array=np.array(la)
display(ha_array.dtype,la_array.dtype)
# Out:
# dtype('int32')
# dtype('float64')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
girl = plt.imread('F:\\2345Downloads\\67818a615cc27189d2a16c869f8cd119.jpg')
display(girl)
# Out:
# array([[[174, 217, 233],
#         [174, 217, 233],
#         [174, 217, 233],
#         ...,
#         [172, 215, 231],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[174, 217, 233],
#         [174, 217, 233],
#         [173, 216, 232],
#         ...,
#         [172, 215, 231],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[174, 217, 233],
#         [173, 216, 232],
#         [173, 216, 232],
#         ...,
#         [173, 216, 232],
#         [173, 216, 232],
#         [174, 217, 233]],
#
#        ...,
#
#        [[163, 209, 225],
#         [163, 209, 225],
#         [164, 210, 226],
#         ...,
#         [173, 216, 232],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[163, 209, 225],
#         [163, 209, 225],
#         [163, 209, 225],
#         ...,
#         [173, 216, 232],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[162, 208, 224],
#         [163, 209, 225],
#         [163, 209, 225],
# ...

# %%
plt.imshow(girl)

# %%
girl_change = girl.copy()

# %%
girl_change.shape
# Out:
# (1080, 1920, 3)

# %%
for i in range(800):
    for j in range(800):
        for k in range(3):
            if girl_change[i][j][k] ==241:
                girl_change[i][j][k] =0
            if girl_change[i][j][k] ==210:
                girl_change[i][j][k] =7
            if girl_change[i][j][k] ==180:
                girl_change[i][j][k] =68
            if girl_change[i][j][k] ==225:
                girl_change[i][j][k] =8

# %%
girl_change
# Out:
# array([[[174, 217, 233],
#         [174, 217, 233],
#         [174, 217, 233],
#         ...,
#         [172, 215, 231],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[174, 217, 233],
#         [174, 217, 233],
#         [173, 216, 232],
#         ...,
#         [172, 215, 231],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[174, 217, 233],
#         [173, 216, 232],
#         [173, 216, 232],
#         ...,
#         [173, 216, 232],
#         [173, 216, 232],
#         [174, 217, 233]],
#
#        ...,
#
#        [[163, 209, 225],
#         [163, 209, 225],
#         [164, 210, 226],
#         ...,
#         [173, 216, 232],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[163, 209, 225],
#         [163, 209, 225],
#         [163, 209, 225],
#         ...,
#         [173, 216, 232],
#         [173, 216, 232],
#         [173, 216, 232]],
#
#        [[162, 208, 224],
#         [163, 209, 225],
#         [163, 209, 225],
# ...

# %%
plt.imshow(girl_change)
